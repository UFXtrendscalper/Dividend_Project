# %% [markdown]
# # polygon.io
#
#     - Using API to get stock dividend data
#     - Note:: on free acount limit is 5 api calls per min
# <!-- link to polygon website-->
# [Polygon](https://polygon.io)

# %%
import requests
import datetime

# %%
api = 'I3RTEm6vso7yOXBhGcYSidwUhRHaSgWy'

# Get today's date
today = datetime.date.today()
# Calculate the date one day after today
fetch_date = today + datetime.timedelta(days=1)
#  format the date to match "Year-month-day"
fetch_date = fetch_date.strftime('%Y-%m-%d')

base_url = f'https://api.polygon.io/v3/reference/dividends?ex_dividend_date={fetch_date}&dividend_type=CD&order=asc&limit=1000&sort=ex_dividend_date&apiKey={api}'
all_results = []

response = requests.get(base_url)
data = response.json()

while "next_url" in data:
    all_results.extend(data["results"])
    next_url = data["next_url"]+"&apiKey={api}"
    response = requests.get(next_url)
    data = response.json()

# Add the last set of results if they exist
if "results" in data:
    all_results.extend(data["results"])

print(all_results)
print(len(all_results))
# Out:
# []
# 0

# %%
# Get today's date
today = datetime.date.today()
# Calculate the date one day after today
fetch_date = today + datetime.timedelta(days=3)
#  format the date to match "Year-mmonth-day"
fetch_date = fetch_date.strftime('%Y-%m-%d')

api = 'I3RTEm6vso7yOXBhGcYSidwUhRHaSgWy'
url = f'https://api.polygon.io/v3/reference/dividends?ex_dividend_date={fetch_date}&dividend_type=CD&order=asc&limit=1000&sort=ex_dividend_date&apiKey={api}'

# make a request to the url 
response = requests.get(url)
# convert the response to json
data = response.json()
# print the data
data
# Out:
# {'results': [{'cash_amount': 0.1,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-24',
#    'record_date': '2023-11-07',
#    'ticker': 'AMAL'},
#   {'cash_amount': 0.7,
#    'currency': 'USD',
#    'declaration_date': '2023-10-25',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'ARLP'},
#   {'cash_amount': 0.155,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'AROC'},
#   {'cash_amount': 0.09,
#    'currency': 'USD',
#    'declaration_date': '2023-10-27',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'BY'},
#   {'cash_amount': 0.16,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'CIVB'},
#   {'cash_amount': 0.36,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-22',
#    'record_date': '2023-11-07',
#    'ticker': 'ETD'},
#   {'cash_amount': 0.15,
#    'currency': 'USD',
#    'declaration_date': '2023-10-27',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'FBK'},
#   {'cash_amount': 0.41,
#    'currency': 'USD',
#    'declaration_date': '2023-09-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-12-01',
#    'record_date': '2023-11-07',
#    'ticker': 'FE'},
#   {'cash_amount': 0.17,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'HBT'},
#   {'cash_amount': 0.15,
#    'currency': 'USD',
#    'declaration_date': '2023-10-25',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'HSII'},
#   {'cash_amount': 0.13,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'HTBK'},
#   {'cash_amount': 0.125,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-12-01',
#    'record_date': '2023-11-07',
#    'ticker': 'INTC'},
#   {'cash_amount': 0.26,
#    'currency': 'USD',
#    'declaration_date': '2023-10-20',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-22',
#    'record_date': '2023-11-07',
#    'ticker': 'INVH'},
#   {'cash_amount': 0.2,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'KMT'},
#   {'cash_amount': 0.33,
#    'currency': 'USD',
#    'declaration_date': '2023-10-25',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-12-01',
#    'record_date': '2023-11-07',
#    'ticker': 'LSTR'},
#   {'cash_amount': 0.2,
#    'currency': 'USD',
#    'declaration_date': '2023-10-18',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-15',
#    'record_date': '2023-11-07',
#    'ticker': 'LVS'},
#   {'cash_amount': 0.005,
#    'currency': 'USD',
#    'declaration_date': '2023-10-18',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'MMLP'},
#   {'cash_amount': 0.1,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'MNSB'},
#   {'cash_amount': 0.01,
#    'currency': 'USD',
#    'declaration_date': '2023-10-23',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-21',
#    'record_date': '2023-11-07',
#    'ticker': 'NBN'},
#   {'cash_amount': 0.05,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-13',
#    'record_date': '2023-11-07',
#    'ticker': 'NMM'},
#   {'cash_amount': 0.4,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'NS'},
#   {'cash_amount': 0.2,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'ORRF'},
#   {'cash_amount': 0.3,
#    'currency': 'USD',
#    'declaration_date': '2023-10-29',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-20',
#    'record_date': '2023-11-07',
#    'ticker': 'PEAK'},
#   {'cash_amount': 0.09,
#    'currency': 'USD',
#    'declaration_date': '2023-10-24',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 1,
#    'pay_date': '2023-12-01',
#    'record_date': '2023-11-07',
#    'ticker': 'SHEN'},
#   {'cash_amount': 0.0266,
#    'currency': 'USD',
#    'declaration_date': '2023-10-25',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-29',
#    'record_date': '2023-11-07',
#    'ticker': 'SIRI'},
#   {'cash_amount': 0.325,
#    'currency': 'USD',
#    'declaration_date': '2023-10-25',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-14',
#    'record_date': '2023-11-07',
#    'ticker': 'SPH'},
#   {'cash_amount': 0.6,
#    'currency': 'USD',
#    'declaration_date': '2023-10-27',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-15',
#    'record_date': '2023-11-07',
#    'ticker': 'TMP'},
#   {'cash_amount': 0.06,
#    'currency': 'USD',
#    'declaration_date': '2023-10-26',
#    'dividend_type': 'CD',
#    'ex_dividend_date': '2023-11-06',
#    'frequency': 4,
#    'pay_date': '2023-11-17',
#    'record_date': '2023-11-07',
#    'ticker': 'WTTR'}],
#  'status': 'OK',
#  'request_id': '381cdec017fa489cd61d75fd3c96b6af'}

# %%
print('-'*20,'[Checking if next URL exists]','-'*20, '\n')
print(" "*10, data.keys())
print('\n','-'*25,'[Number of Results]','-'*25)
print(" "*35,len(data['results']))
# Out:
# -------------------- [Checking if next URL exists] --------------------
#
#            dict_keys(['results', 'status', 'request_id'])
#
#  ------------------------- [Number of Results] -------------------------
#                                     28

# %%
#  create a dateframe from the response
import pandas as pd

df = pd.DataFrame(data['results'])
df
# Out:
#     cash_amount currency declaration_date dividend_type ex_dividend_date  \
# 0        0.1000      USD       2023-10-24            CD       2023-11-06
# 1        0.7000      USD       2023-10-25            CD       2023-11-06
# 2        0.1550      USD       2023-10-26            CD       2023-11-06
# 3        0.0900      USD       2023-10-27            CD       2023-11-06
# 4        0.1600      USD       2023-10-26            CD       2023-11-06
# 5        0.3600      USD       2023-10-24            CD       2023-11-06
# 6        0.1500      USD       2023-10-27            CD       2023-11-06
# 7        0.4100      USD       2023-09-26            CD       2023-11-06
# 8        0.1700      USD       2023-10-24            CD       2023-11-06
# 9        0.1500      USD       2023-10-25            CD       2023-11-06
# 10       0.1300      USD       2023-10-26            CD       2023-11-06
# 11       0.1250      USD       2023-10-26            CD       2023-11-06
# 12       0.2600      USD       2023-10-20            CD       2023-11-06
# 13       0.2000      USD       2023-10-24            CD       2023-11-06
# 14       0.3300      USD       2023-10-25            CD       2023-11-06
# 15       0.2000      USD       2023-10-18            CD       2023-11-06
# 16       0.0050      USD       2023-10-18            CD       2023-11-06
# 17       0.1000      USD       2023-10-24            CD       2023-11-06
# 18       0.0100      USD       2023-10-23            CD       2023-11-06
# 19       0.0500      USD       2023-10-26            CD       2023-11-06
# 20       0.4000      USD       2023-10-26            CD       2023-11-06
# 21       0.2000      USD       2023-10-24            CD       2023-11-06
# 22       0.3000      USD       2023-10-29            CD       2023-11-06
# 23       0.0900      USD       2023-10-24            CD       2023-11-06
# 24       0.0266      USD       2023-10-25            CD       2023-11-06
# 25       0.3250      USD       2023-10-25            CD       2023-11-06
# 26       0.6000      USD       2023-10-27            CD       2023-11-06
# 27       0.0600      USD       2023-10-26            CD       2023-11-06
#
#     frequency    pay_date record_date ticker
# 0           4  2023-11-24  2023-11-07   AMAL
# 1           4  2023-11-14  2023-11-07   ARLP
# 2           4  2023-11-14  2023-11-07   AROC
# 3           4  2023-11-21  2023-11-07     BY
# 4           4  2023-11-21  2023-11-07   CIVB
# 5           4  2023-11-22  2023-11-07    ETD
# 6           4  2023-11-21  2023-11-07    FBK
# 7           4  2023-12-01  2023-11-07     FE
# 8           4  2023-11-14  2023-11-07    HBT
# 9           4  2023-11-21  2023-11-07   HSII
# 10          4  2023-11-21  2023-11-07   HTBK
# 11          4  2023-12-01  2023-11-07   INTC
# 12          4  2023-11-22  2023-11-07   INVH
# 13          4  2023-11-21  2023-11-07    KMT
# 14          4  2023-12-01  2023-11-07   LSTR
# 15          4  2023-11-15  2023-11-07    LVS
# 16          4  2023-11-14  2023-11-07   MMLP
# 17          4  2023-11-14  2023-11-07   MNSB
# 18          4  2023-11-21  2023-11-07    NBN
# 19          4  2023-11-13  2023-11-07    NMM
# 20          4  2023-11-14  2023-11-07     NS
# 21          4  2023-11-14  2023-11-07   ORRF
# 22          4  2023-11-20  2023-11-07   PEAK
# 23          1  2023-12-01  2023-11-07   SHEN
# 24          4  2023-11-29  2023-11-07   SIRI
# 25          4  2023-11-14  2023-11-07    SPH
# 26          4  2023-11-15  2023-11-07    TMP
# 27          4  2023-11-17  2023-11-07   WTTR

# %%
# create a list from the dataframe ticker column
ticker_list = df['ticker'].tolist()
print(ticker_list)
# Out:
# ['AMAL', 'ARLP', 'AROC', 'BY', 'CIVB', 'ETD', 'FBK', 'FE', 'HBT', 'HSII', 'HTBK', 'INTC', 'INVH', 'KMT', 'LSTR', 'LVS', 'MMLP', 'MNSB', 'NBN', 'NMM', 'NS', 'ORRF', 'PEAK', 'SHEN', 'SIRI', 'SPH', 'TMP', 'WTTR']

# %%
# get the close price for each ticker in the list from yfinance
import yfinance as yf
today = datetime.date.today()
ticker_prices = yf.download(ticker_list, period='1m', prepost=True, interval="1d", rounding=True)['Close']
ticker_prices
# Out:
# [*********************100%***********************]  28 of 28 completed
#              AMAL   ARLP   AROC     BY   CIVB    ETD    FBK     FE    HBT  \
# Date
# 2023-11-03  19.14  23.78  14.19  20.12  15.43  27.16  32.59  37.01  18.93
#
#             HSII  ...    NBN    NMM     NS   ORRF   PEAK   SHEN   SIRI    SPH  \
# Date              ...
# 2023-11-03  25.4  ...  50.56  22.39  17.67  22.22  17.03  24.38  4.785  17.71
#
#              TMP  WTTR
# Date
# 2023-11-03  53.9  7.59
#
# [1 rows x 28 columns]

# %%
# transpose the dataframe
ticker_prices = ticker_prices.T
ticker_prices
# Out:
# Date  2023-11-03
# AMAL      19.140
# ARLP      23.780
# AROC      14.190
# BY        20.120
# CIVB      15.430
# ETD       27.160
# FBK       32.590
# FE        37.010
# HBT       18.930
# HSII      25.400
# HTBK       8.740
# INTC      37.740
# INVH      31.940
# KMT       23.930
# LSTR     169.930
# LVS       49.160
# MMLP       2.590
# MNSB      20.000
# NBN       50.560
# NMM       22.390
# NS        17.670
# ORRF      22.220
# PEAK      17.030
# SHEN      24.380
# SIRI       4.785
# SPH       17.710
# TMP       53.900
# WTTR       7.590

# %%
# # drop column 2023-11-01
# ticker_prices = ticker_prices.drop(columns=['2023-11-01'])
# ticker_prices

# %%
# rename the column to close price
ticker_prices.columns = ['close_price']
ticker_prices
# Out:
#       close_price
# AMAL       19.140
# ARLP       23.780
# AROC       14.190
# BY         20.120
# CIVB       15.430
# ETD        27.160
# FBK        32.590
# FE         37.010
# HBT        18.930
# HSII       25.400
# HTBK        8.740
# INTC       37.740
# INVH       31.940
# KMT        23.930
# LSTR      169.930
# LVS        49.160
# MMLP        2.590
# MNSB       20.000
# NBN        50.560
# NMM        22.390
# NS         17.670
# ORRF       22.220
# PEAK       17.030
# SHEN       24.380
# SIRI        4.785
# SPH        17.710
# TMP        53.900
# WTTR        7.590

# %%
df2 = df.copy()
df2['close_Prices'] = df['ticker'].map(ticker_prices['close_price']) 
df2
# Out:
#     cash_amount currency declaration_date dividend_type ex_dividend_date  \
# 0        0.1000      USD       2023-10-24            CD       2023-11-06
# 1        0.7000      USD       2023-10-25            CD       2023-11-06
# 2        0.1550      USD       2023-10-26            CD       2023-11-06
# 3        0.0900      USD       2023-10-27            CD       2023-11-06
# 4        0.1600      USD       2023-10-26            CD       2023-11-06
# 5        0.3600      USD       2023-10-24            CD       2023-11-06
# 6        0.1500      USD       2023-10-27            CD       2023-11-06
# 7        0.4100      USD       2023-09-26            CD       2023-11-06
# 8        0.1700      USD       2023-10-24            CD       2023-11-06
# 9        0.1500      USD       2023-10-25            CD       2023-11-06
# 10       0.1300      USD       2023-10-26            CD       2023-11-06
# 11       0.1250      USD       2023-10-26            CD       2023-11-06
# 12       0.2600      USD       2023-10-20            CD       2023-11-06
# 13       0.2000      USD       2023-10-24            CD       2023-11-06
# 14       0.3300      USD       2023-10-25            CD       2023-11-06
# 15       0.2000      USD       2023-10-18            CD       2023-11-06
# 16       0.0050      USD       2023-10-18            CD       2023-11-06
# 17       0.1000      USD       2023-10-24            CD       2023-11-06
# 18       0.0100      USD       2023-10-23            CD       2023-11-06
# 19       0.0500      USD       2023-10-26            CD       2023-11-06
# 20       0.4000      USD       2023-10-26            CD       2023-11-06
# 21       0.2000      USD       2023-10-24            CD       2023-11-06
# 22       0.3000      USD       2023-10-29            CD       2023-11-06
# 23       0.0900      USD       2023-10-24            CD       2023-11-06
# 24       0.0266      USD       2023-10-25            CD       2023-11-06
# 25       0.3250      USD       2023-10-25            CD       2023-11-06
# 26       0.6000      USD       2023-10-27            CD       2023-11-06
# 27       0.0600      USD       2023-10-26            CD       2023-11-06
#
#     frequency    pay_date record_date ticker  close_Prices
# 0           4  2023-11-24  2023-11-07   AMAL        19.140
# 1           4  2023-11-14  2023-11-07   ARLP        23.780
# 2           4  2023-11-14  2023-11-07   AROC        14.190
# 3           4  2023-11-21  2023-11-07     BY        20.120
# 4           4  2023-11-21  2023-11-07   CIVB        15.430
# 5           4  2023-11-22  2023-11-07    ETD        27.160
# 6           4  2023-11-21  2023-11-07    FBK        32.590
# 7           4  2023-12-01  2023-11-07     FE        37.010
# 8           4  2023-11-14  2023-11-07    HBT        18.930
# 9           4  2023-11-21  2023-11-07   HSII        25.400
# 10          4  2023-11-21  2023-11-07   HTBK         8.740
# 11          4  2023-12-01  2023-11-07   INTC        37.740
# 12          4  2023-11-22  2023-11-07   INVH        31.940
# 13          4  2023-11-21  2023-11-07    KMT        23.930
# 14          4  2023-12-01  2023-11-07   LSTR       169.930
# 15          4  2023-11-15  2023-11-07    LVS        49.160
# 16          4  2023-11-14  2023-11-07   MMLP         2.590
# 17          4  2023-11-14  2023-11-07   MNSB        20.000
# 18          4  2023-11-21  2023-11-07    NBN        50.560
# 19          4  2023-11-13  2023-11-07    NMM        22.390
# 20          4  2023-11-14  2023-11-07     NS        17.670
# 21          4  2023-11-14  2023-11-07   ORRF        22.220
# 22          4  2023-11-20  2023-11-07   PEAK        17.030
# 23          1  2023-12-01  2023-11-07   SHEN        24.380
# 24          4  2023-11-29  2023-11-07   SIRI         4.785
# 25          4  2023-11-14  2023-11-07    SPH        17.710
# 26          4  2023-11-15  2023-11-07    TMP        53.900
# 27          4  2023-11-17  2023-11-07   WTTR         7.590

# %%
df3 = df2.copy()
# calculate the percentage of the dividend
df3['percentage'] = (df2['cash_amount'] / df2['close_Prices'])*100
#  calculate the yearly percentage based on frequency
df3['yearly_percentage'] = (df3['percentage'] * df3['frequency'])
df3
# Out:
#     cash_amount currency declaration_date dividend_type ex_dividend_date  \
# 0        0.1000      USD       2023-10-24            CD       2023-11-06
# 1        0.7000      USD       2023-10-25            CD       2023-11-06
# 2        0.1550      USD       2023-10-26            CD       2023-11-06
# 3        0.0900      USD       2023-10-27            CD       2023-11-06
# 4        0.1600      USD       2023-10-26            CD       2023-11-06
# 5        0.3600      USD       2023-10-24            CD       2023-11-06
# 6        0.1500      USD       2023-10-27            CD       2023-11-06
# 7        0.4100      USD       2023-09-26            CD       2023-11-06
# 8        0.1700      USD       2023-10-24            CD       2023-11-06
# 9        0.1500      USD       2023-10-25            CD       2023-11-06
# 10       0.1300      USD       2023-10-26            CD       2023-11-06
# 11       0.1250      USD       2023-10-26            CD       2023-11-06
# 12       0.2600      USD       2023-10-20            CD       2023-11-06
# 13       0.2000      USD       2023-10-24            CD       2023-11-06
# 14       0.3300      USD       2023-10-25            CD       2023-11-06
# 15       0.2000      USD       2023-10-18            CD       2023-11-06
# 16       0.0050      USD       2023-10-18            CD       2023-11-06
# 17       0.1000      USD       2023-10-24            CD       2023-11-06
# 18       0.0100      USD       2023-10-23            CD       2023-11-06
# 19       0.0500      USD       2023-10-26            CD       2023-11-06
# 20       0.4000      USD       2023-10-26            CD       2023-11-06
# 21       0.2000      USD       2023-10-24            CD       2023-11-06
# 22       0.3000      USD       2023-10-29            CD       2023-11-06
# 23       0.0900      USD       2023-10-24            CD       2023-11-06
# 24       0.0266      USD       2023-10-25            CD       2023-11-06
# 25       0.3250      USD       2023-10-25            CD       2023-11-06
# 26       0.6000      USD       2023-10-27            CD       2023-11-06
# 27       0.0600      USD       2023-10-26            CD       2023-11-06
#
#     frequency    pay_date record_date ticker  close_Prices  percentage  \
# 0           4  2023-11-24  2023-11-07   AMAL        19.140    0.522466
# 1           4  2023-11-14  2023-11-07   ARLP        23.780    2.943650
# 2           4  2023-11-14  2023-11-07   AROC        14.190    1.092319
# 3           4  2023-11-21  2023-11-07     BY        20.120    0.447316
# 4           4  2023-11-21  2023-11-07   CIVB        15.430    1.036941
# 5           4  2023-11-22  2023-11-07    ETD        27.160    1.325479
# 6           4  2023-11-21  2023-11-07    FBK        32.590    0.460264
# 7           4  2023-12-01  2023-11-07     FE        37.010    1.107809
# 8           4  2023-11-14  2023-11-07    HBT        18.930    0.898045
# 9           4  2023-11-21  2023-11-07   HSII        25.400    0.590551
# 10          4  2023-11-21  2023-11-07   HTBK         8.740    1.487414
# 11          4  2023-12-01  2023-11-07   INTC        37.740    0.331214
# 12          4  2023-11-22  2023-11-07   INVH        31.940    0.814026
# 13          4  2023-11-21  2023-11-07    KMT        23.930    0.835771
# 14          4  2023-12-01  2023-11-07   LSTR       169.930    0.194198
# 15          4  2023-11-15  2023-11-07    LVS        49.160    0.406835
# 16          4  2023-11-14  2023-11-07   MMLP         2.590    0.193050
# 17          4  2023-11-14  2023-11-07   MNSB        20.000    0.500000
# 18          4  2023-11-21  2023-11-07    NBN        50.560    0.019778
# 19          4  2023-11-13  2023-11-07    NMM        22.390    0.223314
# 20          4  2023-11-14  2023-11-07     NS        17.670    2.263724
# 21          4  2023-11-14  2023-11-07   ORRF        22.220    0.900090
# 22          4  2023-11-20  2023-11-07   PEAK        17.030    1.761597
# 23          1  2023-12-01  2023-11-07   SHEN        24.380    0.369155
# 24          4  2023-11-29  2023-11-07   SIRI         4.785    0.555904
# 25          4  2023-11-14  2023-11-07    SPH        17.710    1.835121
# 26          4  2023-11-15  2023-11-07    TMP        53.900    1.113173
# 27          4  2023-11-17  2023-11-07   WTTR         7.590    0.790514
#
#     yearly_percentage
# 0            2.089864
# 1           11.774601
# 2            4.369274
# 3            1.789264
# 4            4.147764
# 5            5.301915
# 6            1.841056
# 7            4.431235
# 8            3.592182
# 9            2.362205
# 10           5.949657
# 11           1.324854
# 12           3.256105
# 13           3.343084
# 14           0.776790
# 15           1.627339
# 16           0.772201
# 17           2.000000
# 18           0.079114
# 19           0.893256
# 20           9.054895
# 21           3.600360
# 22           7.046389
# 23           0.369155
# 24           2.223615
# 25           7.340486
# 26           4.452690
# 27           3.162055

# %%
# drop rows with missing values
df3 = df3.dropna()
# sort the dataframe by yearly_percentage
df3 = df3.sort_values(by=['yearly_percentage'], ascending=False)
df3
# Out:
#     cash_amount currency declaration_date dividend_type ex_dividend_date  \
# 1        0.7000      USD       2023-10-25            CD       2023-11-06
# 20       0.4000      USD       2023-10-26            CD       2023-11-06
# 25       0.3250      USD       2023-10-25            CD       2023-11-06
# 22       0.3000      USD       2023-10-29            CD       2023-11-06
# 10       0.1300      USD       2023-10-26            CD       2023-11-06
# 5        0.3600      USD       2023-10-24            CD       2023-11-06
# 26       0.6000      USD       2023-10-27            CD       2023-11-06
# 7        0.4100      USD       2023-09-26            CD       2023-11-06
# 2        0.1550      USD       2023-10-26            CD       2023-11-06
# 4        0.1600      USD       2023-10-26            CD       2023-11-06
# 21       0.2000      USD       2023-10-24            CD       2023-11-06
# 8        0.1700      USD       2023-10-24            CD       2023-11-06
# 13       0.2000      USD       2023-10-24            CD       2023-11-06
# 12       0.2600      USD       2023-10-20            CD       2023-11-06
# 27       0.0600      USD       2023-10-26            CD       2023-11-06
# 9        0.1500      USD       2023-10-25            CD       2023-11-06
# 24       0.0266      USD       2023-10-25            CD       2023-11-06
# 0        0.1000      USD       2023-10-24            CD       2023-11-06
# 17       0.1000      USD       2023-10-24            CD       2023-11-06
# 6        0.1500      USD       2023-10-27            CD       2023-11-06
# 3        0.0900      USD       2023-10-27            CD       2023-11-06
# 15       0.2000      USD       2023-10-18            CD       2023-11-06
# 11       0.1250      USD       2023-10-26            CD       2023-11-06
# 19       0.0500      USD       2023-10-26            CD       2023-11-06
# 14       0.3300      USD       2023-10-25            CD       2023-11-06
# 16       0.0050      USD       2023-10-18            CD       2023-11-06
# 23       0.0900      USD       2023-10-24            CD       2023-11-06
# 18       0.0100      USD       2023-10-23            CD       2023-11-06
#
#     frequency    pay_date record_date ticker  close_Prices  percentage  \
# 1           4  2023-11-14  2023-11-07   ARLP        23.780    2.943650
# 20          4  2023-11-14  2023-11-07     NS        17.670    2.263724
# 25          4  2023-11-14  2023-11-07    SPH        17.710    1.835121
# 22          4  2023-11-20  2023-11-07   PEAK        17.030    1.761597
# 10          4  2023-11-21  2023-11-07   HTBK         8.740    1.487414
# 5           4  2023-11-22  2023-11-07    ETD        27.160    1.325479
# 26          4  2023-11-15  2023-11-07    TMP        53.900    1.113173
# 7           4  2023-12-01  2023-11-07     FE        37.010    1.107809
# 2           4  2023-11-14  2023-11-07   AROC        14.190    1.092319
# 4           4  2023-11-21  2023-11-07   CIVB        15.430    1.036941
# 21          4  2023-11-14  2023-11-07   ORRF        22.220    0.900090
# 8           4  2023-11-14  2023-11-07    HBT        18.930    0.898045
# 13          4  2023-11-21  2023-11-07    KMT        23.930    0.835771
# 12          4  2023-11-22  2023-11-07   INVH        31.940    0.814026
# 27          4  2023-11-17  2023-11-07   WTTR         7.590    0.790514
# 9           4  2023-11-21  2023-11-07   HSII        25.400    0.590551
# 24          4  2023-11-29  2023-11-07   SIRI         4.785    0.555904
# 0           4  2023-11-24  2023-11-07   AMAL        19.140    0.522466
# 17          4  2023-11-14  2023-11-07   MNSB        20.000    0.500000
# 6           4  2023-11-21  2023-11-07    FBK        32.590    0.460264
# 3           4  2023-11-21  2023-11-07     BY        20.120    0.447316
# 15          4  2023-11-15  2023-11-07    LVS        49.160    0.406835
# 11          4  2023-12-01  2023-11-07   INTC        37.740    0.331214
# 19          4  2023-11-13  2023-11-07    NMM        22.390    0.223314
# 14          4  2023-12-01  2023-11-07   LSTR       169.930    0.194198
# 16          4  2023-11-14  2023-11-07   MMLP         2.590    0.193050
# 23          1  2023-12-01  2023-11-07   SHEN        24.380    0.369155
# 18          4  2023-11-21  2023-11-07    NBN        50.560    0.019778
#
#     yearly_percentage
# 1           11.774601
# 20           9.054895
# 25           7.340486
# 22           7.046389
# 10           5.949657
# 5            5.301915
# 26           4.452690
# 7            4.431235
# 2            4.369274
# 4            4.147764
# 21           3.600360
# 8            3.592182
# 13           3.343084
# 12           3.256105
# 27           3.162055
# 9            2.362205
# 24           2.223615
# 0            2.089864
# 17           2.000000
# 6            1.841056
# 3            1.789264
# 15           1.627339
# 11           1.324854
# 19           0.893256
# 14           0.776790
# 16           0.772201
# 23           0.369155
# 18           0.079114

# %%
# query the dataframe for yearly_percentage greater than 5
df3 = df3.query('yearly_percentage > 5')
df3[['cash_amount','ex_dividend_date','frequency','pay_date','ticker','close_Prices','percentage','yearly_percentage']]
# Out:
#     cash_amount ex_dividend_date  frequency    pay_date ticker  close_Prices  \
# 1         0.700       2023-11-06          4  2023-11-14   ARLP         23.78
# 20        0.400       2023-11-06          4  2023-11-14     NS         17.67
# 25        0.325       2023-11-06          4  2023-11-14    SPH         17.71
# 22        0.300       2023-11-06          4  2023-11-20   PEAK         17.03
# 10        0.130       2023-11-06          4  2023-11-21   HTBK          8.74
# 5         0.360       2023-11-06          4  2023-11-22    ETD         27.16
#
#     percentage  yearly_percentage
# 1     2.943650          11.774601
# 20    2.263724           9.054895
# 25    1.835121           7.340486
# 22    1.761597           7.046389
# 10    1.487414           5.949657
# 5     1.325479           5.301915

# %%
# create a list of the tickers
ticker_list = df3['ticker'].tolist()
print(ticker_list)
print('Length =', len(ticker_list))
# Out:
# ['ARLP', 'NS', 'SPH', 'PEAK', 'HTBK', 'ETD']
# Length = 6

# %%
#
# todo : run the dividend prediction model on the list of tickers
short_list = ['NYCB', 'HAFC', 'OCFC']

buy_df = df3[['cash_amount','ex_dividend_date','frequency','pay_date','ticker','close_Prices','percentage','yearly_percentage']]
buy_df = buy_df[buy_df['ticker'].isin(short_list)]
buy_df

# %%
# create a column that contains the number of shares to buy based on 100$ investment
buy_df['num_shares_100'] = 100 / buy_df['close_Prices']
# convert to integer
buy_df['num_shares_100'] = buy_df['num_shares_100'].astype(int)
buy_df['purchase_cost'] = buy_df['num_shares_100'] * buy_df['close_Prices']
buy_df['next_div_pay'] = buy_df['num_shares_100'] * buy_df['cash_amount']
buy_df['yr_div_pay'] = buy_df['next_div_pay'] * buy_df['frequency']
buy_df
